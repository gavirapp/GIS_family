# %% [markdown]
# ### 1. Labs to get started with:
# http://comet.lehman.cuny.edu/owen/teaching/datasci/choroplethLab.html
#
#
#
# ### Some Key Resources:
# GitHub account and Gist start
# http://apprentice.craic.com/tutorials/20
#
#
# - Web page plugins:
# http://apprentice.craic.com/tutorials?page=1
#
#
# - GIS data formats:
# http://apprentice.craic.com/tutorials/28
#
#
# - Folium Package:
# https://github.com/python-visualization/folium
#
#
# - General Data Science material
# https://github.com/joelgrus/data-science-from-scratch
#
#
#
# ### GIS Homework:
# 	- http://comet.lehman.cuny.edu/owen/teaching/datasci/hw3.html
# 	- http://comet.lehman.cuny.edu/owen/teaching/datasci/hw8.html
# 	- http://comet.lehman.cuny.edu/owen/teaching/datasci/hw9.html (do parts 4 -7)
#
#
#
#
#
# ### Data Science Intro:
# 	- http://comet.lehman.cuny.edu/owen/teaching/mat128/sp2019.html
#
#
#
#
#
# ### Python (part of a CUNY course - will get you up and running on Python as it relates to Data Science):
#
# 1. List comprehensions
# https://treyhunner.com/2015/12/python-list-comprehensions-now-in-color/
#
# 2. Basic graphing:
# https://matplotlib.org/
#
# 3. Graphing exercises:
# http://comet.lehman.cuny.edu/owen/teaching/datasci/plotRecipes.html
#
# 4. Data Structures:
# 	- Lists & tuples: http://news.e-scribe.com/397
# 	- dictionary: http://www.pythontutor.com/visualize.html#mode=display
# 	- Reading and writing files: http://comet.lehman.cuny.edu/owen/teaching/datasci/csvEx.py
# 		(data: http://comet.lehman.cuny.edu/owen/teaching/datasci/in.csv)
# 5. Homework:
# 	- a.  http://comet.lehman.cuny.edu/owen/teaching/datasci/hw1.html
# 	- b.  http://comet.lehman.cuny.edu/owen/teaching/datasci/hw2.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(0,10,101)
y = x**2

plt.plot(x,y)

plt.title('Graph of $y = x^2$')
# Out:
# Text(0.5, 1.0, 'Graph of $y = x^2$')

# %%
import folium

# %%
from folium.plugins import MarkerCluster

# %%
m = folium.Map([44,-73], zoom_start = 7)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(location = [43, -75],
popup = "First Marker",
icon = folium.Icon(color = 'red', icon='ok-sign')
).add_to(marker_cluster)

folium.Marker(location = [45, -73.5],
popup = "Second Marker",
icon = folium.Icon(color = 'red', icon='remove-sign')
).add_to(marker_cluster)

folium.Marker(
    location = [45, -75],
    popup = 'This is a cluster',
    icon = None
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
